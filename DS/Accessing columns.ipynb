# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 581          582         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 581  Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.0      1
#
#      Parch      Fare Cabin Embarked
# 581      1  110.8833   C68        C

# %%
df['Cabin']

# %%
df['Embarked']=0

# %%
del df['Name']

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Fare  Cabin  \
# 0              1         0       3    male  22.0      1      0     0      0
# 1              2         1       1  female  38.0      1      0     0      0
# 2              3         1       3  female  26.0      0      0     0      0
# 3              4         1       1  female  35.0      1      0     0      0
# 4              5         0       3    male  35.0      0      0     0      0
# ..           ...       ...     ...     ...   ...    ...    ...   ...    ...
# 886          887         0       2    male  27.0      0      0     0      0
# 887          888         1       1  female  19.0      0      0     0      0
# 888          889         0       3  female   NaN      1      2     0      0
# 889          890         1       1    male  26.0      0      0     0      0
# 890          891         0       3    male  32.0      0      0     0      0
#
#     Embarked
# 0          S
# 1          C
# ...
